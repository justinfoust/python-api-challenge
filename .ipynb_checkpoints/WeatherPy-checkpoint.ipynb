# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    #print(lat_lng)
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url = "http://api.openweathermap.org/data/2.5/weather"
#query_dict = \
#{
#    'appid': api_key,
#}

cities_array = ['London','Tokyo','foobar','Austin']
output = []

for i in range(len(cities)):
    response = requests.get \
    (
        "http://api.openweathermap.org/data/2.5/weather",
        params= \
        {
            'appid': api_key,
            'q': cities[i],
            'units': 'metric'
        }
    )
    
    if response.json()['cod'] == 200:
        output.append(response.json())
        print(f'{i+1} | {cities[i]} | Weather data recorded')
    else:
        print(f'{i+1} | {cities[i]} | City not found, skipping...')
        
print(f'========== Finished Retreiving Data ==========')
# Out:
# 1 | kruisfontein | Weather data recorded
# 2 | wainwright | Weather data recorded
# 3 | longyearbyen | Weather data recorded
# 4 | kapaa | Weather data recorded
# 5 | busselton | Weather data recorded
# 6 | tabulbah | City not found, skipping...
# 7 | san vicente de canete | Weather data recorded
# 8 | pevek | Weather data recorded
# 9 | barrow | Weather data recorded
# 10 | yellowknife | Weather data recorded
# 11 | lavrentiya | Weather data recorded
# 12 | abnub | Weather data recorded
# 13 | novosergiyevka | Weather data recorded
# 14 | albany | Weather data recorded
# 15 | wulanhaote | City not found, skipping...
# 16 | punta arenas | Weather data recorded
# 17 | namatanai | Weather data recorded
# 18 | sitka | Weather data recorded
# 19 | tilichiki | Weather data recorded
# 20 | hithadhoo | Weather data recorded
# 21 | angoram | Weather data recorded
# 22 | vilyuysk | Weather data recorded
# 23 | togur | Weather data recorded
# 24 | taolanaro | City not found, skipping...
# 25 | mabaruma | Weather data recorded
# 26 | kavieng | Weather data recorded
# 27 | dudinka | Weather data recorded
# 28 | rikitea | Weather data recorded
# 29 | hermanus | Weather data recorded
# 30 | puerto ayora | Weather data recorded
# 31 | praya | Weather data recorded
# 32 | ushuaia | Weather data recorded
# 33 | san patricio | Weather data recorded
# 34 | altagracia de orituco | Weather data recorded
# 35 | nikolskoye | Weather data recorded
# 36 | jamestown | Weather data recorded
# 37 | kaitangata | Weather data recorded
# 38 | lagoa | Weather data recorded
# 39 | ust-kuyga | Weather data recorded
# 40 | natal | Weather data recorded
# 41 | berlevag | Weather data recorded
# 42 | mataura | Weather data recorded
# 43 | lebu | Weather data recorded
# 44 | severo-kurilsk | Weather data recorded
# 45 | attawapiskat | City not found, skipping...
# 46 | qaanaaq | Weather data recorded
# 47 | juba | Weather data recorded
# 48 | port elizabeth | Weather data recorded
# 49 | angren | Weather data recorded
# 50 | sakaiminato | Weather data recorded
# 51 | hilo | Weather data recorded
# 52 | ondangwa | Weather data recorded
# 53 | esperance | Weather data recorded
# 54 | new norfolk | Weather data recorded
# 55 | ous | Weather data recorded
# 56 | pochutla | Weather data recorded
# 57 | orange cove | Weather data recorded
# 58 | norman wells | Weather data recorded
# 59 | san ramon | Weather data recorded
# 60 | kikwit | Weather data recorded
# 61 | mount gambier | Weather data recorded
# 62 | yaan | Weather data recorded
# 63 | anadyr | Weather data recorded
# 64 | saskylakh | Weather data recorded
# 65 | pinar del rio | Weather data recorded
# 66 | grand forks | Weather data recorded
# 67 | olafsvik | City not found, skipping...
# 68 | pinczow | Weather data recorded
# 69 | bambous virieux | Weather data recorded
# 70 | grand river south east | City not found, skipping...
# 71 | tucuman | Weather data recorded
# 72 | constitucion | Weather data recorded
# 73 | moundou | Weather data recorded
# 74 | bluff | Weather data recorded
# 75 | tuktoyaktuk | Weather data recorded
# 76 | namibe | Weather data recorded
# 77 | seoul | Weather data recorded
# 78 | sumbawa | City not found, skipping...
# 79 | zhengjiatun | Weather data recorded
# 80 | port hardy | Weather data recorded
# 81 | yambio | City not found, skipping...
# 82 | arraial do cabo | Weather data recorded
# 83 | maneadero | City not found, skipping...
# 84 | kosa | Weather data recorded
# 85 | vaini | Weather data recorded
# 86 | torbay | Weather data recorded
# 87 | nizhneyansk | City not found, skipping...
# 88 | tiksi | Weather data recorded
# 89 | stromness | Weather data recorded
# 90 | oranjestad | Weather data recorded
# 91 | meiringen | Weather data recorded
# 92 | gornopravdinsk | Weather data recorded
# 93 | victoria | Weather data recorded
# 94 | hobart | Weather data recorded
# 95 | port blair | Weather data recorded
# 96 | codrington | Weather data recorded
# 97 | kodiak | Weather data recorded
# 98 | flinders | Weather data recorded
# 99 | puro | Weather data recorded
# 100 | bajina basta | Weather data recorded
# 101 | amderma | City not found, skipping...
# 102 | manama | Weather data recorded
# 103 | cidreira | Weather data recorded
# 104 | probota | Weather data recorded
# 105 | adre | Weather data recorded
# 106 | kailua | Weather data recorded
# 107 | souillac | Weather data recorded
# 108 | illoqqortoormiut | City not found, skipping...
# 109 | goderich | Weather data recorded
# 110 | barcelos | Weather data recorded
# 111 | dingle | Weather data recorded
# 112 | mafinga | City not found, skipping...
# 113 | saint-philippe | Weather data recorded
# 114 | buluang | Weather data recorded
# 115 | tautira | Weather data recorded
# 116 | mar del plata | Weather data recorded
# 117 | taoudenni | Weather data recorded
# 118 | tupik | Weather data recorded
# 119 | hasaki | Weather data recorded
# 120 | saint joseph | Weather data recorded
# 121 | gamba | Weather data recorded
# 122 | ilulissat | Weather data recorded
# 123 | dera din panah | City not found, skipping...
# 124 | broken hill | Weather data recorded
# 125 | leningradskiy | Weather data recorded
# 126 | bethel | Weather data recorded
# 127 | waipawa | Weather data recorded
# 128 | karratha | Weather data recorded
# 129 | muzquiz | City not found, skipping...
# 130 | salisbury | Weather data recorded
# 131 | atuona | Weather data recorded
# 132 | douentza | Weather data recorded
# 133 | takoradi | Weather data recorded
# 134 | katsuura | Weather data recorded
# 135 | bhadasar | Weather data recorded
# 136 | ahuimanu | Weather data recorded
# 137 | cherskiy | Weather data recorded
# 138 | fort pierce | Weather data recorded
# 139 | beckley | Weather data recorded
# 140 | sentyabrskiy | City not found, skipping...
# 141 | bredasdorp | Weather data recorded
# 142 | chuy | Weather data recorded
# 143 | tumannyy | City not found, skipping...
# 144 | brae | Weather data recorded
# 145 | avarua | Weather data recorded
# 146 | karamea | City not found, skipping...
# 147 | camacha | Weather data recorded
# 148 | jackson | Weather data recorded
# 149 | kaitong | Weather data recorded
# 150 | griffith | Weather data recorded
# 151 | tocopilla | Weather data recorded
# 152 | linqing | Weather data recorded
# 153 | vlissingen | Weather data recorded
# 154 | fukue | Weather data recorded
# 155 | port alfred | Weather data recorded
# 156 | palmeirais | Weather data recorded
# 157 | nguiu | City not found, skipping...
# 158 | lamu | Weather data recorded
# 159 | lyuban | Weather data recorded
# 160 | thohoyandou | Weather data recorded
# 161 | srednyaya akhtuba | Weather data recorded
# 162 | talcahuano | Weather data recorded
# 163 | san policarpo | Weather data recorded
# 164 | srednekolymsk | Weather data recorded
# 165 | hambantota | Weather data recorded
# 166 | castro | Weather data recorded
# 167 | iranshahr | Weather data recorded
# 168 | butaritari | Weather data recorded
# 169 | zhongshan | Weather data recorded
# 170 | ribeira grande | Weather data recorded
# 171 | cape town | Weather data recorded
# 172 | carnarvon | Weather data recorded
# 173 | oktyabrskiy | Weather data recorded
# 174 | lyngseidet | Weather data recorded
# 175 | tasiilaq | Weather data recorded
# 176 | sao filipe | Weather data recorded
# 177 | thompson | Weather data recorded
# 178 | mahon | Weather data recorded
# 179 | huarmey | Weather data recorded
# 180 | luderitz | Weather data recorded
# 181 | provideniya | Weather data recorded
# 182 | chokurdakh | Weather data recorded
# 183 | kemijarvi | City not found, skipping...
# 184 | caravelas | Weather data recorded
# 185 | georgetown | Weather data recorded
# 186 | egvekinot | Weather data recorded
# 187 | rantepao | Weather data recorded
# 188 | barentsburg | City not found, skipping...
# 189 | bababe | City not found, skipping...
# 190 | shimoda | Weather data recorded
# 191 | troitskoye | Weather data recorded
# 192 | ponta do sol | Weather data recorded
# 193 | cabo san lucas | Weather data recorded
# 194 | tanete | Weather data recorded
# 195 | beringovskiy | Weather data recorded
# 196 | gorno-chuyskiy | City not found, skipping...
# 197 | paamiut | Weather data recorded
# 198 | ovalle | Weather data recorded
# 199 | washington | Weather data recorded
# 200 | alofi | Weather data recorded
# 201 | acapulco | Weather data recorded
# 202 | bosaso | Weather data recorded
# 203 | christchurch | Weather data recorded
# 204 | nemuro | Weather data recorded
# 205 | kutum | Weather data recorded
# 206 | eenhana | Weather data recorded
# 207 | ust-koksa | Weather data recorded
# 208 | ngukurr | City not found, skipping...
# 209 | tsihombe | City not found, skipping...
# 210 | bubaque | Weather data recorded
# 211 | dikson | Weather data recorded
# 212 | bathsheba | Weather data recorded
# 213 | quatre cocos | Weather data recorded
# 214 | kununurra | Weather data recorded
# 215 | damphu | Weather data recorded
# 216 | provost | Weather data recorded
# 217 | den helder | Weather data recorded
# 218 | aktash | City not found, skipping...
# 219 | chiredzi | Weather data recorded
# 220 | upernavik | Weather data recorded
# 221 | isangel | Weather data recorded
# 222 | khatanga | Weather data recorded
# 223 | manokwari | Weather data recorded
# 224 | yerbogachen | Weather data recorded
# 225 | vardo | Weather data recorded
# 226 | yulara | Weather data recorded
# 227 | kapit | Weather data recorded
# 228 | manta | Weather data recorded
# 229 | manaure | Weather data recorded
# 230 | tara | Weather data recorded
# 231 | husavik | Weather data recorded
# 232 | airai | Weather data recorded
# 233 | salalah | Weather data recorded
# 234 | lander | Weather data recorded
# 235 | ridgetown | Weather data recorded
# 236 | leibnitz | Weather data recorded
# 237 | goundam | Weather data recorded
# 238 | yar-sale | Weather data recorded
# 239 | nueve de julio | Weather data recorded
# 240 | shache | Weather data recorded
# 241 | springbok | Weather data recorded
# 242 | pisco | Weather data recorded
# 243 | bac lieu | City not found, skipping...
# 244 | narsaq | Weather data recorded
# 245 | east london | Weather data recorded
# 246 | kelvington | Weather data recorded
# 247 | faanui | Weather data recorded
# 248 | west wendover | Weather data recorded
# 249 | stokmarknes | Weather data recorded
# 250 | broome | Weather data recorded
# 251 | aborlan | Weather data recorded
# 252 | aklavik | Weather data recorded
# 253 | okhotsk | Weather data recorded
# 254 | calabozo | Weather data recorded
# 255 | muscat | Weather data recorded
# 256 | ishurdi | Weather data recorded
# 257 | mount isa | Weather data recorded
# 258 | boyuibe | Weather data recorded
# 259 | lata | Weather data recorded
# 260 | maxixe | Weather data recorded
# 261 | nguru | Weather data recorded
# 262 | kalabo | Weather data recorded
# 263 | kholodnyy | Weather data recorded
# 264 | guerrero negro | Weather data recorded
# 265 | cayenne | Weather data recorded
# 266 | chokwe | City not found, skipping...
# 267 | taganak | Weather data recorded
# 268 | havre-saint-pierre | Weather data recorded
# 269 | roma | Weather data recorded
# 270 | forestville | Weather data recorded
# 271 | camana | City not found, skipping...
# 272 | alotau | City not found, skipping...
# 273 | borba | Weather data recorded
# 274 | ngunguru | Weather data recorded
# 275 | mizpe ramon | City not found, skipping...
# 276 | maua | Weather data recorded
# 277 | belmonte | Weather data recorded
# 278 | the pas | Weather data recorded
# 279 | alice springs | Weather data recorded
# 280 | tromso | Weather data recorded
# 281 | kalmunai | Weather data recorded
# 282 | tuy hoa | Weather data recorded
# 283 | pandrup | Weather data recorded
# 284 | granada | Weather data recorded
# 285 | boma | Weather data recorded
# 286 | la palma | Weather data recorded
# 287 | hovd | Weather data recorded
# 288 | qasigiannguit | Weather data recorded
# 289 | shingu | Weather data recorded
# 290 | katobu | Weather data recorded
# 291 | pamanukan | Weather data recorded
# 292 | lorengau | Weather data recorded
# 293 | saldanha | Weather data recorded
# 294 | pogar | Weather data recorded
# 295 | morondava | Weather data recorded
# 296 | bainbridge | Weather data recorded
# 297 | jalu | Weather data recorded
# 298 | ahipara | Weather data recorded
# 299 | axim | Weather data recorded
# 300 | almaznyy | Weather data recorded
# 301 | naugarzan | City not found, skipping...
# 302 | taburi | City not found, skipping...
# 303 | richards bay | Weather data recorded
# 304 | inhambane | Weather data recorded
# 305 | nikolsk | Weather data recorded
# 306 | tessalit | Weather data recorded
# 307 | hamilton | Weather data recorded
# 308 | saint george | Weather data recorded
# 309 | presidencia roque saenz pena | Weather data recorded
# 310 | montana | Weather data recorded
# 311 | ostrovnoy | Weather data recorded
# 312 | le port | Weather data recorded
# 313 | coxim | Weather data recorded
# 314 | gigmoto | Weather data recorded
# 315 | san rafael | Weather data recorded
# 316 | eyl | Weather data recorded
# 317 | kahului | Weather data recorded
# 318 | catamarca | City not found, skipping...
# 319 | waitati | Weather data recorded
# 320 | zhigansk | Weather data recorded
# 321 | mahebourg | Weather data recorded
# 322 | clyde river | Weather data recorded
# 323 | comodoro rivadavia | Weather data recorded
# 324 | xuddur | Weather data recorded
# 325 | balsas | Weather data recorded
# 326 | mapastepec | Weather data recorded
# 327 | siverek | Weather data recorded
# 328 | albanel | Weather data recorded
# 329 | mvuma | Weather data recorded
# 330 | kajaani | Weather data recorded
# 331 | basco | Weather data recorded
# 332 | tezu | Weather data recorded
# 333 | tombouctou | Weather data recorded
# 334 | edd | Weather data recorded
# 335 | sembakung | Weather data recorded
# 336 | el higo | Weather data recorded
# 337 | saleaula | City not found, skipping...
# 338 | miranorte | City not found, skipping...
# 339 | barra do garcas | Weather data recorded
# 340 | ozernovskiy | Weather data recorded
# 341 | nouadhibou | Weather data recorded
# 342 | tuatapere | Weather data recorded
# 343 | mazagao | Weather data recorded
# 344 | kaeo | Weather data recorded
# 345 | northam | Weather data recorded
# 346 | galgani | City not found, skipping...
# 347 | pizarro | Weather data recorded
# 348 | sigli | Weather data recorded
# 349 | long beach | Weather data recorded
# 350 | havre | Weather data recorded
# 351 | yumen | Weather data recorded
# 352 | paredon | Weather data recorded
# 353 | algiers | Weather data recorded
# 354 | hofn | Weather data recorded
# 355 | signagi | City not found, skipping...
# 356 | lolua | City not found, skipping...
# 357 | belushya guba | City not found, skipping...
# 358 | college | Weather data recorded
# 359 | itarema | Weather data recorded
# 360 | bonavista | Weather data recorded
# 361 | saint-francois | Weather data recorded
# 362 | meadow lake | Weather data recorded
# 363 | kapfenberg | Weather data recorded
# 364 | bowen | Weather data recorded
# 365 | pacific grove | Weather data recorded
# 366 | killybegs | Weather data recorded
# 367 | marcona | City not found, skipping...
# 368 | bucerias | Weather data recorded
# 369 | celestun | Weather data recorded
# 370 | sibolga | Weather data recorded
# 371 | belyy yar | Weather data recorded
# 372 | bonfim | Weather data recorded
# 373 | sur | Weather data recorded
# 374 | klaksvik | Weather data recorded
# 375 | bengkulu | City not found, skipping...
# 376 | waingapu | Weather data recorded
# 377 | sola | Weather data recorded
# 378 | yingcheng | Weather data recorded
# 379 | vestmannaeyjar | Weather data recorded
# 380 | harpenden | Weather data recorded
# 381 | manzil jamil | City not found, skipping...
# 382 | bambanglipuro | Weather data recorded
# 383 | kasulu | Weather data recorded
# 384 | stephenville | Weather data recorded
# 385 | coquimbo | Weather data recorded
# 386 | namie | Weather data recorded
# 387 | ust-maya | Weather data recorded
# 388 | hobyo | Weather data recorded
# 389 | kazalinsk | City not found, skipping...
# 390 | qui nhon | City not found, skipping...
# 391 | lewisporte | Weather data recorded
# 392 | linxia | Weather data recorded
# 393 | deoli | Weather data recorded
# 394 | arroyo | Weather data recorded
# 395 | jamsa | Weather data recorded
# 396 | turbat | Weather data recorded
# 397 | andenes | City not found, skipping...
# 398 | la libertad | Weather data recorded
# 399 | half moon bay | Weather data recorded
# 400 | fairbanks | Weather data recorded
# 401 | nuuk | Weather data recorded
# 402 | deputatskiy | Weather data recorded
# 403 | jasper | Weather data recorded
# 404 | yeppoon | Weather data recorded
# 405 | sangar | Weather data recorded
# 406 | nanortalik | Weather data recorded
# 407 | jian | Weather data recorded
# 408 | tual | Weather data recorded
# 409 | umm kaddadah | Weather data recorded
# 410 | kavaratti | Weather data recorded
# 411 | vaitupu | City not found, skipping...
# 412 | plastun | Weather data recorded
# 413 | pedernales | Weather data recorded
# 414 | varca | Weather data recorded
# 415 | vostok | Weather data recorded
# 416 | jingdezhen | Weather data recorded
# 417 | bajo baudo | City not found, skipping...
# 418 | carmelo | Weather data recorded
# 419 | kanungu | Weather data recorded
# 420 | labuhan | Weather data recorded
# 421 | redwater | Weather data recorded
# 422 | taree | Weather data recorded
# 423 | likasi | Weather data recorded
# 424 | kenai | Weather data recorded
# 425 | tupelo | Weather data recorded
# 426 | atar | Weather data recorded
# 427 | langwedel | Weather data recorded
# 428 | sinnamary | Weather data recorded
# 429 | sumbe | Weather data recorded
# 430 | hienghene | Weather data recorded
# 431 | vao | Weather data recorded
# 432 | san quintin | Weather data recorded
# 433 | nhulunbuy | Weather data recorded
# 434 | cairns | Weather data recorded
# 435 | mys shmidta | City not found, skipping...
# 436 | fortuna | Weather data recorded
# 437 | zalegoshch | Weather data recorded
# 438 | bonthe | Weather data recorded
# 439 | port lincoln | Weather data recorded
# 440 | sept-iles | Weather data recorded
# 441 | ocos | Weather data recorded
# 442 | balakhta | Weather data recorded
# 443 | san cristobal | Weather data recorded
# 444 | dunedin | Weather data recorded
# 445 | bodden town | Weather data recorded
# 446 | praia | Weather data recorded
# 447 | mumford | Weather data recorded
# 448 | baruun-urt | Weather data recorded
# 449 | palabuhanratu | City not found, skipping...
# 450 | korla | City not found, skipping...
# 451 | longlac | City not found, skipping...
# 452 | baglan | Weather data recorded
# 453 | geraldton | Weather data recorded
# 454 | aksarka | Weather data recorded
# 455 | hervey bay | Weather data recorded
# 456 | buchanan | Weather data recorded
# 457 | santiago | Weather data recorded
# 458 | kudahuvadhoo | Weather data recorded
# 459 | oskarshamn | Weather data recorded
# 460 | atikokan | Weather data recorded
# 461 | freeport | Weather data recorded
# 462 | fethiye | Weather data recorded
# 463 | warmbad | Weather data recorded
# 464 | saint-joseph | Weather data recorded
# 465 | katherine | Weather data recorded
# 466 | talnakh | Weather data recorded
# 467 | waksma | City not found, skipping...
# 468 | macapa | Weather data recorded
# 469 | pulandian | Weather data recorded
# 470 | williston | Weather data recorded
# 471 | tayshet | Weather data recorded
# 472 | qaqortoq | Weather data recorded
# 473 | carmichael | Weather data recorded
# 474 | banda aceh | Weather data recorded
# 475 | hunza | City not found, skipping...
# 476 | esna | Weather data recorded
# 477 | jiangyou | Weather data recorded
# 478 | kawalu | Weather data recorded
# 479 | babanusah | City not found, skipping...
# 480 | poquoson | Weather data recorded
# 481 | nakama | Weather data recorded
# 482 | sakakah | City not found, skipping...
# 483 | ayan | Weather data recorded
# 484 | kapuskasing | Weather data recorded
# 485 | hirado | Weather data recorded
# 486 | sao joao da barra | Weather data recorded
# 487 | doha | Weather data recorded
# 488 | kologriv | Weather data recorded
# 489 | surt | Weather data recorded
# 490 | nazarovo | Weather data recorded
# 491 | mponela | Weather data recorded
# 492 | kharabali | Weather data recorded
# 493 | oranjemund | Weather data recorded
# 494 | baykit | Weather data recorded
# 495 | mayya | Weather data recorded
# 496 | duz | City not found, skipping...
# 497 | neiafu | Weather data recorded
# 498 | chapais | Weather data recorded
# 499 | puerto carreno | Weather data recorded
# 500 | westport | Weather data recorded
# 501 | kautokeino | Weather data recorded
# 502 | asau | City not found, skipping...
# 503 | ganta | Weather data recorded
# 504 | fort nelson | Weather data recorded
# 505 | kyrylivka | Weather data recorded
# 506 | oktyabrskoye | Weather data recorded
# 507 | hohhot | Weather data recorded
# 508 | byron bay | Weather data recorded
# 509 | killarney | Weather data recorded
# 510 | grindavik | Weather data recorded
# 511 | lazaro cardenas | Weather data recorded
# 512 | tura | Weather data recorded
# 513 | sao miguel do araguaia | Weather data recorded
# 514 | taunggyi | Weather data recorded
# 515 | ivanteyevka | Weather data recorded
# 516 | zhangye | Weather data recorded
# 517 | zurrieq | Weather data recorded
# 518 | selenginsk | Weather data recorded
# 519 | qingyuan | Weather data recorded
# 520 | kamenskoye | City not found, skipping...
# 521 | coihaique | Weather data recorded
# 522 | kamaishi | Weather data recorded
# 523 | ocampo | Weather data recorded
# 524 | khor | Weather data recorded
# 525 | merauke | Weather data recorded
# 526 | paka | Weather data recorded
# 527 | yauya | Weather data recorded
# 528 | ubatuba | Weather data recorded
# 529 | point fortin | Weather data recorded
# 530 | dayong | Weather data recorded
# 531 | jaumave | Weather data recorded
# 532 | aktau | Weather data recorded
# 533 | birao | Weather data recorded
# 534 | ochakiv | Weather data recorded
# 535 | manono | Weather data recorded
# 536 | hami | Weather data recorded
# 537 | vanimo | Weather data recorded
# 538 | bay saint louis | Weather data recorded
# 539 | port-cartier | Weather data recorded
# 540 | rambha | Weather data recorded
# 541 | cabedelo | Weather data recorded
# 542 | mundo nuevo | Weather data recorded
# 543 | gat | Weather data recorded
# 544 | santa ana | Weather data recorded
# 545 | vila do maio | Weather data recorded
# 546 | padang | Weather data recorded
# 547 | ordu | Weather data recorded
# 548 | portland | Weather data recorded
# 549 | gaoual | Weather data recorded
# 550 | manaus | Weather data recorded
# 551 | champerico | Weather data recorded
# 552 | te anau | Weather data recorded
# 553 | saint anthony | Weather data recorded
# 554 | rio cuarto | Weather data recorded
# 555 | oshawa | Weather data recorded
# 556 | jarvakandi | Weather data recorded
# 557 | harper | Weather data recorded
# 558 | cilegon | Weather data recorded
# 559 | avera | Weather data recorded
# 560 | davenda | Weather data recorded
# 561 | bandarbeyla | Weather data recorded
# 562 | puerto narino | Weather data recorded
# 563 | khandyga | Weather data recorded
# 564 | kidal | Weather data recorded
# 565 | the valley | Weather data recorded
# 566 | nanchang | Weather data recorded
# 567 | azare | Weather data recorded
# 568 | thiruvananthapuram | Weather data recorded
# 569 | lubango | Weather data recorded
# 570 | sawakin | Weather data recorded
# 571 | coffs harbour | Weather data recorded
# 572 | pushkinskiye gory | Weather data recorded
# 573 | seymchan | Weather data recorded
# 574 | kalat | Weather data recorded
# 575 | okato | Weather data recorded
# 576 | los llanos de aridane | Weather data recorded
# 577 | lewistown | Weather data recorded
# 578 | kijang | Weather data recorded
# 579 | duldurga | Weather data recorded
# 580 | eitorf | Weather data recorded
# 581 | hailar | Weather data recorded
# 582 | meulaboh | Weather data recorded
# 583 | san vicente | Weather data recorded
# 584 | chalus | Weather data recorded
# 585 | svarstad | Weather data recorded
# 586 | dedovichi | Weather data recorded
# 587 | requena | Weather data recorded
# 588 | high prairie | Weather data recorded
# 589 | lake park | Weather data recorded
# 590 | pachino | Weather data recorded
# 591 | umzimvubu | City not found, skipping...
# 592 | kamennomostskiy | Weather data recorded
# 593 | nabire | Weather data recorded
# 594 | morropon | Weather data recorded
# 595 | falealupo | City not found, skipping...
# 596 | tomatlan | Weather data recorded
# 597 | mbekenyera | Weather data recorded
# 598 | coahuayana | Weather data recorded
# 599 | itoman | Weather data recorded
# 600 | xai-xai | Weather data recorded
# 601 | zachagansk | City not found, skipping...
# ========== Finished Retreiving Data ==========

# %%
len(output)
# Out:
# 539

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df_list = []

for i in range(len(output)):
    df_list.append \
    ([
        output[i]['name'],   # City name
        output[i]['sys']['country'],   # Country
        time.strftime("%d %b %Y %H:%M:%S" ,time.gmtime(output[i]['dt'])),   # Date
        output[i]['coord']['lat'],   # Latitude
        output[i]['coord']['lon'],   # Longitude
        output[i]['main']['temp_max'],   # Max temperature
        output[i]['main']['humidity'],   # Humidity
        output[i]['clouds']['all'],   # Cloudiness
        output[i]['wind']['speed']   # Wind speed
    ])

result_df = pd.DataFrame \
(
    df_list, 
    columns= \
    [
        'Name',
        'Country',
        'Date',
        'Latitude',
        'Longitude',
        'Max Temperature',
        'Humidity',
        'Cloudiness',
        'Wind Speed'
    ]
)

record_date = result_df.loc[0,'Date']

result_df.to_csv(path_or_buf='output.csv',index=False)
result_df.head()
# Out:
#            Name Country                  Date  Latitude  Longitude  \
# 0  Kruisfontein      ZA  16 Oct 2019 02:14:03    -34.00      24.73
# 1    Wainwright      CA  16 Oct 2019 02:14:04     52.84    -110.86
# 2  Longyearbyen      NO  16 Oct 2019 02:14:04     78.22      15.63
# 3         Kapaa      US  16 Oct 2019 02:14:04     22.08    -159.32
# 4     Busselton      AU  16 Oct 2019 02:14:05    -33.64     115.35
#
#    Max Temperature  Humidity  Cloudiness  Wind Speed
# 0            13.55        59           0       2.118
# 1             2.95        69         100       8.533
# 2            -6.00        79          20       2.600
# 3            28.00        74          40       7.700
# 4            19.44        33          47       2.470

# %%
result_df.loc[0,'Date']
# Out:
# '16 Oct 2019 02:14:03'

# %%
output[1]
# Out:
# {'coord': {'lon': -110.86, 'lat': 52.84},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'model',
#  'main': {'temp': 2.95,
#   'pressure': 1010,
#   'humidity': 69,
#   'temp_min': 2.95,
#   'temp_max': 2.95,
#   'sea_level': 1010,
#   'grnd_level': 930.7},
#  'wind': {'speed': 8.533, 'deg': 140},
#  'clouds': {'all': 100},
#  'dt': 1571192044,
#  'sys': {'country': 'CA', 'sunrise': 1571147341, 'sunset': 1571185747},
#  'timezone': -21600,
#  'id': 6175059,
#  'name': 'Wainwright',
#  'cod': 200}

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Max Temperature'])

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.title(f'Max Temperature vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Temp_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Humidity vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Humidity_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Cloudiness vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Clouds_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Wind Speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f'Wind Speed vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Wind_v_Lat.png')

plt.show()
